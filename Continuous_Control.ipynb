# %% [markdown]
# # Continuous Control
#
# ---
#
# In this notebook, you will learn how to use the Unity ML-Agents environment for the second project of the [Deep Reinforcement Learning Nanodegree](https://www.udacity.com/course/deep-reinforcement-learning-nanodegree--nd893) program.
#
# ### 1. Start the Environment
#
# We begin by importing the necessary packages.  If the code cell below returns an error, please revisit the project instructions to double-check that you have installed [Unity ML-Agents](https://github.com/Unity-Technologies/ml-agents/blob/master/docs/Installation.md) and [NumPy](http://www.numpy.org/).

# %%
# !pip -q install ./python
# Out:
# tensorflow 1.7.1 has requirement numpy>=1.13.3, but you'll have numpy 1.12.1 which is incompatible.
# ipython 6.5.0 has requirement prompt-toolkit<2.0.0,>=1.0.15, but you'll have prompt-toolkit 3.0.5 which is incompatible.

# %%
from unityagents import UnityEnvironment
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# Next, we will start the environment!  **_Before running the code cell below_**, change the `file_name` parameter to match the location of the Unity environment that you downloaded.
#
# - **Mac**: `"path/to/Reacher.app"`
# - **Windows** (x86): `"path/to/Reacher_Windows_x86/Reacher.exe"`
# - **Windows** (x86_64): `"path/to/Reacher_Windows_x86_64/Reacher.exe"`
# - **Linux** (x86): `"path/to/Reacher_Linux/Reacher.x86"`
# - **Linux** (x86_64): `"path/to/Reacher_Linux/Reacher.x86_64"`
# - **Linux** (x86, headless): `"path/to/Reacher_Linux_NoVis/Reacher.x86"`
# - **Linux** (x86_64, headless): `"path/to/Reacher_Linux_NoVis/Reacher.x86_64"`
#
# For instance, if you are using a Mac, then you downloaded `Reacher.app`.  If this file is in the same folder as the notebook, then the line below should appear as follows:
# ```
# env = UnityEnvironment(file_name="Reacher.app")
# ```

# %%
env = UnityEnvironment(file_name='/data/Reacher_Linux_NoVis/Reacher.x86_64')
# Out:
# INFO:unityagents:
# 'Academy' started successfully!
# Unity Academy name: Academy
#         Number of Brains: 1
#         Number of External Brains : 1
#         Lesson number : 0
#         Reset Parameters :
# 		goal_size -> 5.0
# 		goal_speed -> 1.0
# Unity brain name: ReacherBrain
#         Number of Visual Observations (per agent): 0
#         Vector Observation space type: continuous
#         Vector Observation space size (per agent): 33
#         Number of stacked Vector Observation: 1
#         Vector Action space type: continuous
#         Vector Action space size (per agent): 4
#         Vector Action descriptions: , , ,

# %% [markdown]
# Environments contain **_brains_** which are responsible for deciding the actions of their associated agents. Here we check for the first brain available, and set it as the default brain we will be controlling from Python.

# %%
# get the default brain
brain_name = env.brain_names[0]
brain = env.brains[brain_name]

# %% [markdown]
# ### 2. Examine the State and Action Spaces
#
# In this environment, a double-jointed arm can move to target locations. A reward of `+0.1` is provided for each step that the agent's hand is in the goal location. Thus, the goal of your agent is to maintain its position at the target location for as many time steps as possible.
#
# The observation space consists of `33` variables corresponding to position, rotation, velocity, and angular velocities of the arm.  Each action is a vector with four numbers, corresponding to torque applicable to two joints.  Every entry in the action vector must be a number between `-1` and `1`.
#
# Run the code cell below to print some information about the environment.

# %%
# reset the environment
env_info = env.reset(train_mode=True)[brain_name]

# number of agents
num_agents = len(env_info.agents)
print('Number of agents:', num_agents)

# size of each action
action_size = brain.vector_action_space_size
print('Size of each action:', action_size)

# examine the state space 
states = env_info.vector_observations
state_size = states.shape[1]
print('There are {} agents. Each observes a state with length: {}'.format(states.shape[0], state_size))
print('The state for the first agent looks like:', states[0])
# Out:
# Number of agents: 20
# Size of each action: 4
# There are 20 agents. Each observes a state with length: 33
# The state for the first agent looks like: [  0.00000000e+00  -4.00000000e+00   0.00000000e+00   1.00000000e+00
#   -0.00000000e+00  -0.00000000e+00  -4.37113883e-08   0.00000000e+00
#    0.00000000e+00   0.00000000e+00   0.00000000e+00   0.00000000e+00
#    0.00000000e+00   0.00000000e+00  -1.00000000e+01   0.00000000e+00
#    1.00000000e+00  -0.00000000e+00  -0.00000000e+00  -4.37113883e-08
#    0.00000000e+00   0.00000000e+00   0.00000000e+00   0.00000000e+00
#    0.00000000e+00   0.00000000e+00   5.75471878e+00  -1.00000000e+00
#    5.55726624e+00   0.00000000e+00   1.00000000e+00   0.00000000e+00
#   -1.68164849e-01]

# %%
from ddpg_agent import Agent
from collections import deque
import torch
#create 20 agents
agents=[Agent(state_size, action_size, i,random_seed=0) for i in range(num_agents)]
Agent.actor_local.load_state_dict(torch.load('checkpoint_actor.pth'))
Agent.critic_local.load_state_dict(torch.load('checkpoint_critic.pth'))

# %%
def ddpg(n_episodes=300, max_t=1000, print_every=100):
    scores_deque = deque(maxlen=100)
    scores = []
    for i_episode in range(1, n_episodes+1):
        score_episode=0
        env_info = env.reset(train_mode=True)[brain_name]
        states=env_info.vector_observations
        for i in range(num_agents):
            agents[i].reset()
        score = np.zeros(num_agents) 
        for t in range(max_t):
            actions=[agents[i].act(states[i]) for i in range(num_agents)]
            env_info = env.step(actions)[brain_name]           # send all actions to tne environment
            next_states = env_info.vector_observations         # get next state (for each agent)
            rewards = env_info.rewards                        # get reward (for each agent)
            dones = env_info.local_done
            for i in range(num_agents):
                agents[i].step(states[i], actions[i], rewards[i], next_states[i], dones[i],t)
            states = next_states  
            score += rewards
            if np.any(dones):                                  # exit loop if episode finished
                break    
        scores_deque.append(np.mean(score))
        scores.append(np.mean(score))
        score_episode=np.mean(score)
        if(score_episode>30):
            print("Awesome score",score_episode)
        print('\rEpisode {}\tcurrent Score: {:.2f}'.format(i_episode, score_episode))
        print('\rEpisode {}\tAverage Score: {:.2f}'.format(i_episode, np.mean(scores_deque)))        
        torch.save(Agent.actor_local.state_dict(), 'checkpoint_actor.pth')
        torch.save(Agent.critic_local.state_dict(), 'checkpoint_critic.pth')
        if(np.mean(scores_deque)>30):
            return scores
        if i_episode % print_every == 0:
            print('\rEpisode {}\tAverage Score: {:.2f}'.format(i_episode, np.mean(scores_deque)))
            
    return scores

from workspace_utils import active_session
 
with active_session():
    # do long-running work here
    scores = ddpg()
    fig = plt.figure()
    ax = fig.add_subplot(111)
    plt.plot(np.arange(1, len(scores)+1), scores)
    plt.ylabel('Score')
    plt.xlabel('Episode #')
    plt.show()
# Out:
# Episode 1	current Score: 0.20
# Episode 1	Average Score: 0.20
# Episode 2	current Score: 0.77
# Episode 2	Average Score: 0.49
# Episode 3	current Score: 1.15
# Episode 3	Average Score: 0.71
# Episode 4	current Score: 1.72
# Episode 4	Average Score: 0.96
# Episode 5	current Score: 2.41
# Episode 5	Average Score: 1.25
# Episode 6	current Score: 2.93
# Episode 6	Average Score: 1.53
# Episode 7	current Score: 3.61
# Episode 7	Average Score: 1.83
# Episode 8	current Score: 3.83
# Episode 8	Average Score: 2.08
# Episode 9	current Score: 4.52
# Episode 9	Average Score: 2.35
# Episode 10	current Score: 5.44
# Episode 10	Average Score: 2.66
# Episode 11	current Score: 6.29
# Episode 11	Average Score: 2.99
# Episode 12	current Score: 7.30
# Episode 12	Average Score: 3.35
# Episode 13	current Score: 7.37
# Episode 13	Average Score: 3.66
# Episode 14	current Score: 8.27
# Episode 14	Average Score: 3.99
# Episode 15	current Score: 8.42
# Episode 15	Average Score: 4.28
# Episode 16	current Score: 8.29
# Episode 16	Average Score: 4.53
# Episode 17	current Score: 9.95
# Episode 17	Average Score: 4.85
# Episode 18	current Score: 11.33
# Episode 18	Average Score: 5.21
# Episode 19	current Score: 10.77
# Episode 19	Average Score: 5.50
# Episode 20	current Score: 11.43
# Episode 20	Average Score: 5.80
# Episode 21	current Score: 13.23
# Episode 21	Average Score: 6.15
# Episode 22	current Score: 12.16
# Episode 22	Average Score: 6.43
# Episode 23	current Score: 14.38
# Episode 23	Average Score: 6.77
# Episode 24	current Score: 14.19
# Episode 24	Average Score: 7.08
# Episode 25	current Score: 13.81
# Episode 25	Average Score: 7.35
# Episode 26	current Score: 13.67
# Episode 26	Average Score: 7.59
# Episode 27	current Score: 14.14
# Episode 27	Average Score: 7.84
# Episode 28	current Score: 15.45
# Episode 28	Average Score: 8.11
# Episode 29	current Score: 16.01
# Episode 29	Average Score: 8.38
# Episode 30	current Score: 16.04
# Episode 30	Average Score: 8.64
# Episode 31	current Score: 15.85
# Episode 31	Average Score: 8.87
# Episode 32	current Score: 18.85
# Episode 32	Average Score: 9.18
# Episode 33	current Score: 19.72
# Episode 33	Average Score: 9.50
# Episode 34	current Score: 19.79
# Episode 34	Average Score: 9.80
# Episode 35	current Score: 19.70
# Episode 35	Average Score: 10.09
# Episode 36	current Score: 19.12
# Episode 36	Average Score: 10.34
# Episode 37	current Score: 21.15
# Episode 37	Average Score: 10.63
# Episode 38	current Score: 21.66
# Episode 38	Average Score: 10.92
# Episode 39	current Score: 20.80
# Episode 39	Average Score: 11.17
# Episode 40	current Score: 21.16
# Episode 40	Average Score: 11.42
# Episode 41	current Score: 22.17
# Episode 41	Average Score: 11.68
# Episode 42	current Score: 22.01
# Episode 42	Average Score: 11.93
# Episode 43	current Score: 26.76
# Episode 43	Average Score: 12.28
# Episode 44	current Score: 24.74
# Episode 44	Average Score: 12.56
# Episode 45	current Score: 27.34
# Episode 45	Average Score: 12.89
# Episode 46	current Score: 26.64
# Episode 46	Average Score: 13.19
# Episode 47	current Score: 26.74
# Episode 47	Average Score: 13.47
# Episode 48	current Score: 26.95
# Episode 48	Average Score: 13.76
# Episode 49	current Score: 27.65
# Episode 49	Average Score: 14.04
# Episode 50	current Score: 28.40
# Episode 50	Average Score: 14.33
# Episode 51	current Score: 29.76
# Episode 51	Average Score: 14.63
# Awesome score 31.5019992959
# Episode 52	current Score: 31.50
# Episode 52	Average Score: 14.95
# Awesome score 31.2674993011
# Episode 53	current Score: 31.27
# Episode 53	Average Score: 15.26
# Awesome score 31.0259993065
# Episode 54	current Score: 31.03
# Episode 54	Average Score: 15.55
# Awesome score 30.8369993107
# Episode 55	current Score: 30.84
# Episode 55	Average Score: 15.83
# Awesome score 32.2074992801
# Episode 56	current Score: 32.21
# Episode 56	Average Score: 16.12
# Awesome score 33.1909992581
# Episode 57	current Score: 33.19
# Episode 57	Average Score: 16.42
# Awesome score 32.0554992835
# Episode 58	current Score: 32.06
# Episode 58	Average Score: 16.69
# Awesome score 32.5809992718
# Episode 59	current Score: 32.58
# Episode 59	Average Score: 16.96
# Awesome score 32.9139992643
# Episode 60	current Score: 32.91
# Episode 60	Average Score: 17.23
# Awesome score 34.1919992357
# Episode 61	current Score: 34.19
# Episode 61	Average Score: 17.51
# Awesome score 33.7359992459
# Episode 62	current Score: 33.74
# Episode 62	Average Score: 17.77
# Awesome score 34.44899923
# Episode 63	current Score: 34.45
# Episode 63	Average Score: 18.03
# Awesome score 34.0709992385
# Episode 64	current Score: 34.07
# Episode 64	Average Score: 18.28
# Awesome score 34.5859992269
# Episode 65	current Score: 34.59
# Episode 65	Average Score: 18.53
# Awesome score 34.8919992201
# Episode 66	current Score: 34.89
# Episode 66	Average Score: 18.78
# Awesome score 34.7074992242
# Episode 67	current Score: 34.71
# Episode 67	Average Score: 19.02
# Awesome score 34.5599992275
# Episode 68	current Score: 34.56
# Episode 68	Average Score: 19.25
# Awesome score 34.5869992269
# Episode 69	current Score: 34.59
# Episode 69	Average Score: 19.47
# Awesome score 33.7269992461
# Episode 70	current Score: 33.73
# Episode 70	Average Score: 19.67
# Awesome score 34.5099992286
# Episode 71	current Score: 34.51
# Episode 71	Average Score: 19.88
# Awesome score 34.6699992251
# Episode 72	current Score: 34.67
# Episode 72	Average Score: 20.09
# Awesome score 35.1709992139
# Episode 73	current Score: 35.17
# Episode 73	Average Score: 20.29
# Awesome score 35.1574992142
# Episode 74	current Score: 35.16
# Episode 74	Average Score: 20.50
# Awesome score 35.6264992037
# Episode 75	current Score: 35.63
# Episode 75	Average Score: 20.70
# Awesome score 34.8439992212
# Episode 76	current Score: 34.84
# Episode 76	Average Score: 20.88
# Awesome score 34.7874992224
# Episode 77	current Score: 34.79
# Episode 77	Average Score: 21.06
# Awesome score 33.9674992408
# Episode 78	current Score: 33.97
# Episode 78	Average Score: 21.23
# Awesome score 33.3589992544
# Episode 79	current Score: 33.36
# Episode 79	Average Score: 21.38
# Awesome score 35.4414992078
# Episode 80	current Score: 35.44
# Episode 80	Average Score: 21.56
# Awesome score 34.8234992216
# Episode 81	current Score: 34.82
# Episode 81	Average Score: 21.72
# Awesome score 33.3079992555
# Episode 82	current Score: 33.31
# Episode 82	Average Score: 21.86
# Awesome score 34.136999237
# Episode 83	current Score: 34.14
# Episode 83	Average Score: 22.01
# Awesome score 34.0784992383
# Episode 84	current Score: 34.08
# Episode 84	Average Score: 22.16
# Awesome score 32.1769992808
# Episode 85	current Score: 32.18
# Episode 85	Average Score: 22.27
# Awesome score 33.7134992464
# Episode 86	current Score: 33.71
# Episode 86	Average Score: 22.41
# Awesome score 32.0874992828
# Episode 87	current Score: 32.09
# Episode 87	Average Score: 22.52
# Awesome score 34.2054992354
# Episode 88	current Score: 34.21
# Episode 88	Average Score: 22.65
# Awesome score 34.3204992329
# Episode 89	current Score: 34.32
# Episode 89	Average Score: 22.78
# Awesome score 33.8449992435
# Episode 90	current Score: 33.84
# Episode 90	Average Score: 22.90
# Awesome score 34.0674992385
# Episode 91	current Score: 34.07
# Episode 91	Average Score: 23.03
# Awesome score 33.3384992548
# Episode 92	current Score: 33.34
# Episode 92	Average Score: 23.14
# Awesome score 31.989499285
# Episode 93	current Score: 31.99
# Episode 93	Average Score: 23.23
# Awesome score 31.9129992867
# Episode 94	current Score: 31.91
# Episode 94	Average Score: 23.33
# Awesome score 31.2889993006
# Episode 95	current Score: 31.29
# Episode 95	Average Score: 23.41
# Awesome score 32.8639992654
# Episode 96	current Score: 32.86
# Episode 96	Average Score: 23.51
# Awesome score 33.3464992546
# Episode 97	current Score: 33.35
# Episode 97	Average Score: 23.61
# Awesome score 32.9119992644
# Episode 98	current Score: 32.91
# Episode 98	Average Score: 23.71
# Awesome score 32.1414992816
# Episode 99	current Score: 32.14
# Episode 99	Average Score: 23.79
# Awesome score 33.4119992532
# Episode 100	current Score: 33.41
# Episode 100	Average Score: 23.89
# Episode 100	Average Score: 23.89
# Awesome score 34.0699992385
# Episode 101	current Score: 34.07
# Episode 101	Average Score: 24.23
# Awesome score 34.2014992355
# Episode 102	current Score: 34.20
# Episode 102	Average Score: 24.56
# Awesome score 34.6909992246
# Episode 103	current Score: 34.69
# Episode 103	Average Score: 24.89
# Awesome score 34.8929992201
# Episode 104	current Score: 34.89
# Episode 104	Average Score: 25.23
# Awesome score 34.045499239
# Episode 105	current Score: 34.05
# Episode 105	Average Score: 25.54
# Awesome score 34.7044992243
# Episode 106	current Score: 34.70
# Episode 106	Average Score: 25.86
# Awesome score 33.8459992435
# Episode 107	current Score: 33.85
# Episode 107	Average Score: 26.16
# Awesome score 32.9419992637
# Episode 108	current Score: 32.94
# Episode 108	Average Score: 26.45
# Awesome score 34.2134992353
# Episode 109	current Score: 34.21
# Episode 109	Average Score: 26.75
# Awesome score 32.1404992816
# Episode 110	current Score: 32.14
# Episode 110	Average Score: 27.02
# Awesome score 32.1574992812
# Episode 111	current Score: 32.16
# Episode 111	Average Score: 27.28
# Awesome score 32.2759992786
# Episode 112	current Score: 32.28
# Episode 112	Average Score: 27.53
# Awesome score 33.2434992569
# Episode 113	current Score: 33.24
# Episode 113	Average Score: 27.79
# Awesome score 32.0984992825
# Episode 114	current Score: 32.10
# Episode 114	Average Score: 28.02
# Awesome score 32.9639992632
# Episode 115	current Score: 32.96
# Episode 115	Average Score: 28.27
# Awesome score 31.8384992884
# Episode 116	current Score: 31.84
# Episode 116	Average Score: 28.50
# Awesome score 30.7314993131
# Episode 117	current Score: 30.73
# Episode 117	Average Score: 28.71
# Awesome score 30.3244993222
# Episode 118	current Score: 30.32
# Episode 118	Average Score: 28.90
# Awesome score 32.746999268
# Episode 119	current Score: 32.75
# Episode 119	Average Score: 29.12
# Awesome score 32.2439992793
# Episode 120	current Score: 32.24
# Episode 120	Average Score: 29.33
# Episode 121	current Score: 29.93
# Episode 121	Average Score: 29.50
# Awesome score 30.1209993267
# Episode 122	current Score: 30.12
# Episode 122	Average Score: 29.68
# Awesome score 31.4749992965
# Episode 123	current Score: 31.47
# Episode 123	Average Score: 29.85
# Awesome score 30.4724993189
# Episode 124	current Score: 30.47
# Episode 124	Average Score: 30.01

# %% [markdown]
# ### 3. Take Random Actions in the Environment
#
# In the next code cell, you will learn how to use the Python API to control the agent and receive feedback from the environment.
#
# Once this cell is executed, you will watch the agent's performance, if it selects an action at random with each time step.  A window should pop up that allows you to observe the agent, as it moves through the environment.
#
# Of course, as part of the project, you'll have to change the code so that the agent is able to use its experience to gradually choose better actions when interacting with the environment!

# %%
env_info = env.reset(train_mode=False)[brain_name]     # reset the environment    
states = env_info.vector_observations                  # get the current state (for each agent)
scores = np.zeros(num_agents)                          # initialize the score (for each agent)
for i in range(2):
    actions = np.random.randn(num_agents, action_size) # select an action (for each agent)
    actions = np.clip(actions, -1, 1)                  # all actions between -1 and 1
    env_info = env.step(actions)[brain_name]           # send all actions to tne environment
    next_states = env_info.vector_observations         # get next state (for each agent)
    rewards = env_info.rewards                         # get reward (for each agent)
    dones = env_info.local_done                        # see if episode finished
    scores += env_info.rewards  
    # update the score (for each agent)
    print(actions[0])
    print(rewards[0])
    states = next_states                               # roll over states to next time step
    if np.any(dones):                                  # exit loop if episode finished
        break
print('Total score (averaged over agents) this episode: {}'.format(np.mean(scores)))

# %% [markdown]
# When finished, you can close the environment.

# %%
env.close()

# %% [markdown]
# ### 4. It's Your Turn!
#
# Now it's your turn to train your own agent to solve the environment!  When training the environment, set `train_mode=True`, so that the line for resetting the environment looks like the following:
# ```python
# env_info = env.reset(train_mode=True)[brain_name]
# ```
